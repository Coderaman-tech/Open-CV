# %% [markdown]
# Pillow Library(PIL)

# %%
my_image = "lenna.png"

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'c:\\Users\\AMAN SHRIVASTAVA\\Open cv'

# %%
image_path = os.path.join(cwd, my_image)
image_path
# Out:
# 'c:\\Users\\AMAN SHRIVASTAVA\\Open cv\\lenna.png'

# %%
from PIL import Image

# %%
image = Image.open(my_image)
type(image)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x258D07067C0>

# %%
image1=Image.open('baboon.png')

# %%
image1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x258D0706AC0>

# %%
image2=Image.open('barbara.png')

# %%
image2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512 at 0x258D24B6910>

# %%
image1.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.imshow(image1)

# %%
image = Image.open(image_path)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x258DBA09AF0>

# %%
print(image.)
